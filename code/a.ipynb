# %%
import pandas as pd

data = {'name':["jon","ann","pter","park"],'loc':["busan","서울","경기","강원"],'age':[10,20,23,10]}

data_pandas = pd.DataFrame(data)

display(data_pandas)
# Out:
#    name    loc  age
# 0   jon  busan   10
# 1   ann     서울   20
# 2  pter     경기   23
# 3  park     강원   10

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,100)
y=np.sin(x)
plt.plot(x,y,marker="x")
# Out:
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
print("iris_dataset의 키 : \n{}".format(iris_dataset.keys()))
# Out:
# iris_dataset의 키 :
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(iris_dataset['DESCR'][:193]+"\n...")
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, pre
# ...

# %%
import mglearn
import matplotlib
import matplotlib.pyplot as plt
matplotlib.get_cachedir()

# 설치된 font를 확인 후 적용
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])
matplotlib.rc('font', family='NanumGothic')

X,Y = mglearn.datasets.make_forge()
mglearn.discrete_scatter(X[:,0],X[:,1],Y)
plt.legend(["클래스 0","class 2"], loc=4)
plt.xlabel("f")
plt.ylabel("s")
print("x.shape : {}".format(X.shape))
# Out:
# x.shape : (26, 2)
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.neighbors import KNeighborsRegressor
import matplotlib
import matplotlib.pyplot as plt
# wave 데이터셋을 훈련 세트와 테스트 세트로 나눕니다.
X, y = mglearn.datasets.make_wave(n_samples=40)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# 이웃의 수를 3으로 하여 모델의 객체를 만듭니다. 
reg = KNeighborsRegressor(n_neighbors=3)
# 훈련 데이터와 타깃을 사용하여 모델을 학습시킵니다.
reg.fit(X_train, y_train)

fig, axes = plt.subplots(1 , 3, figsize=(15, 4))
# -3과 3 사이에 1,000개의 데이터 포인트를 만듭니다. 
line = np.linspace(-3, 3, 1000).reshape(-1, 1)
for n_neighbors, ax in zip([1, 3, 9], axes): # 1, 3, 9 이웃을 사용한 예측을 합니다.
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train, y_train) 
    ax.plot(line, reg.predict(line))
    ax.plot(X_train, y_train, '^', c=mglearn.cm2(0), markersize=8) 
    ax.plot(X_test, y_test, 'v', c=mglearn.cm2(1), markersize=8)

    ax.set_title(
        "{} 이웃의 훈련 스코어: {:.2f} 테스트 스코어: {:.2f}".format( n_neighbors, reg.score(X_train, y_train), reg.score(X_test, y_test)))
    ax.set_xlabel("특성") 
    ax.set_ylabel("타깃")
    axes[0].legend(["모델 예측", "훈련 데이터/타깃","테스트 데이터/타깃"], loc="best")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\qkr99\Desktop\학교\ML\code\a.ipynb Cell 7' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/qkr99/Desktop/%ED%95%99%EA%B5%90/ML/code/a.ipynb#ch0000006?line=3'>4</a> # wave 데이터셋을 훈련 세트와 테스트 세트로 나눕니다.
#       <a href='vscode-notebook-cell:/c%3A/Users/qkr99/Desktop/%ED%95%99%EA%B5%90/ML/code/a.ipynb#ch0000006?line=4'>5</a> X, y = mglearn.datasets.make_wave(n_samples=40)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/qkr99/Desktop/%ED%95%99%EA%B5%90/ML/code/a.ipynb#ch0000006?line=6'>7</a> X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
#       <a href='vscode-notebook-cell:/c%3A/Users/qkr99/Desktop/%ED%95%99%EA%B5%90/ML/code/a.ipynb#ch0000006?line=8'>9</a> # 이웃의 수를 3으로 하여 모델의 객체를 만듭니다.
#      <a href='vscode-notebook-cell:/c%3A/Users/qkr99/Desktop/%ED%95%99%EA%B5%90/ML/code/a.ipynb#ch0000006?line=9'>10</a> reg = KNeighborsRegressor(n_neighbors=3)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.datasets import make_blobs
matplotlib.rcParams['axes.unicode_minus'] = False

X, y = make_blobs(random_state=42) 
mglearn.discrete_scatter(X[:, 0], X[:, 1], y) 
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(["클래스 0", "클래스 1", "클래스 2"])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

X, y = mglearn.datasets.make_wave(n_samples=100)
line = np.linspace(-3, 3, 1000, endpoint=False).reshape(-1, 1)

reg = DecisionTreeRegressor(min_samples_split=3).fit(X, y)
plt.plot(line, reg.predict(line), label="Decision Tree")

reg = LinearRegression().fit(X, y)
plt.plot(line, reg.predict(line), '--', label="Linear Regression")

plt.plot(X[:,0], y, 'o', c='k')
plt.ylabel("regression output")
plt.xlabel("input feature")
plt.legend(loc="best")
# Out:
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\qkr99\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
